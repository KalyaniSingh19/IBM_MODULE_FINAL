# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Notebook

# %% [markdown]
# ## Introduction
# This notebook serves as a comprehensive guide to various aspects of data science, including languages, libraries, tools, and practical examples of arithmetic expressions. It aims to provide a foundational understanding of key concepts and practical applications in the field of data science.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science.
# - Identify key libraries used in Data Science.
# - Describe various Data Science tools and their applications.
# - Demonstrate basic arithmetic operations with examples.
# - Convert time units in practical scenarios.

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool         | Description                     |
# |--------------|---------------------------------|
# | Jupyter      | Interactive computing environment|
# | Anaconda     | Package manager for Python/R    |
# | Git          | Version control system           |
# | Tableau      | Data visualization tool          |
# | RStudio      | IDE for R                       |

# %% [markdown]
# ## Arithmetic Expression Examples
# In this section, we will explore basic arithmetic operations, such as addition, multiplication, and their applications in programming.

# %%
# Exercise 8 - Multiply and add numbers
result = (5 * 10) + (3 * 2)
result
# Out:
# 56

# %%
# Exercise 9 - Convert minutes to hours
def convert_minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

convert_minutes_to_hours(120)  # Example conversion
# Out:
# 2.0

# %% [markdown]
# ## Author
# Kalyani Singh
